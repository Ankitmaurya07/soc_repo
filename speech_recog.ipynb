# %%
import numpy as np
import tensorflow as tf
from tensorflow.keras.layers import Dense,Input
import librosa as lb
import pandas as pd
import librosa.display
import os
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder
from tensorflow.keras.utils import to_categorical
from sklearn.metrics import classification_report
from tensorflow.keras.layers import Dense
from sklearn.preprocessing import LabelBinarizer, StandardScaler

# %%
def extract_features(main_dir, list_of_features):
    features_list = []
    labels = []

    for subfolder in os.listdir(main_dir):
        subfolder_path = os.path.join(main_dir, subfolder)
        if os.path.isdir(subfolder_path):
            # Iterate over each audio file in the subfolder
            for filename in os.listdir(subfolder_path):
                if filename.endswith('.wav'):
                    file_path = os.path.join(subfolder_path, filename)
                    
                    y, sr = librosa.load(file_path)

                    features = []
                    if 'mfcc' in list_of_features:
                        mfcc = librosa.feature.mfcc(y=y, sr=sr, n_mfcc=13)
                        features.extend(mfcc.mean(axis=1))

                    if 'chroma' in list_of_features:
                        stft = np.abs(librosa.stft(y))
                        chroma = librosa.feature.chroma_stft(S=stft, sr=sr)
                        features.extend(chroma.mean(axis=1))

                    if 'melspectrogram' in list_of_features:
                        mel_spect = librosa.feature.melspectrogram(y=y, sr=sr)
                        mel_spect_db = librosa.power_to_db(mel_spect, ref=np.max)
                        features.extend(mel_spect_db.mean(axis=1))

                    features_list.append(features)
                    labels.append(filename[7])  

    return features_list, labels

# %%
def load_data(test_size1=0.2):
    filename = r'C:\Users\pashu\OneDrive\Desktop\speech_recong_project\Audio_Speech_Actors_01-24'
    filename1 = r'C:\Users\pashu\OneDrive\Desktop\speech_recong_project\Audio_Song_Actors_01-24'
    listf = ['mfcc', 'chroma', 'melspectrogram']
    
    features, labels = extract_features(main_dir=filename, list_of_features=listf)
    features1, labels1 = extract_features(main_dir=filename1, list_of_features=listf)
    
    features_array = np.array(features, dtype=np.float32)
    labels_array = np.array(labels)
    features_array1 = np.array(features1, dtype=np.float32)
    labels_array1 = np.array(labels1)
    
    features_array2 = np.concatenate((features_array, features_array1), axis=0)
    labels_array2 = np.concatenate((labels_array, labels_array1), axis=0)
    
    scaler = StandardScaler()
    features_array2 = scaler.fit_transform(features_array2)
    
    lb = LabelBinarizer()
    labels_one_hot = lb.fit_transform(labels_array2)
    
    X_train, X_test, y_train, y_test = train_test_split(features_array2, labels_one_hot, test_size=test_size1, random_state=42)
    return X_train, X_test, y_train, y_test, lb

# %%
X_train, X_test, y_train, y_test, lb = load_data()

# %%
model = tf.keras.Sequential([
    Dense(300, activation='relu', input_shape=(X_train.shape[1],)),
    Dense(y_train.shape[1], activation='softmax')
])
# Out:
# C:\Users\pashu\AppData\Roaming\Python\Python312\site-packages\keras\src\layers\core\dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)

# %%
model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])  
model.fit(X_train, y_train, epochs=200, batch_size=256, validation_split=0.1)
test_loss, test_accuracy = model.evaluate(X_test, y_test, verbose=2)
print(f'Test Accuracy: {test_accuracy*100:.4f}')
# Out:
# Epoch 1/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 2s 58ms/step - accuracy: 0.1984 - loss: 2.1205 - val_accuracy: 0.2690 - val_loss: 1.8023
# Epoch 2/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.3603 - loss: 1.6601 - val_accuracy: 0.3604 - val_loss: 1.6762
# Epoch 3/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.4682 - loss: 1.4510 - val_accuracy: 0.4061 - val_loss: 1.5373
# Epoch 4/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - accuracy: 0.5312 - loss: 1.3072 - val_accuracy: 0.4365 - val_loss: 1.4403
# Epoch 5/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.5802 - loss: 1.2407 - val_accuracy: 0.4619 - val_loss: 1.3586
# Epoch 6/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.6130 - loss: 1.1797 - val_accuracy: 0.5127 - val_loss: 1.3013
# Epoch 7/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.6336 - loss: 1.1042 - val_accuracy: 0.5584 - val_loss: 1.2549
# Epoch 8/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.6604 - loss: 1.0485 - val_accuracy: 0.5533 - val_loss: 1.2143
# Epoch 9/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.
# Epoch 134/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 1.0000 - loss: 0.0391 - val_accuracy: 0.7919 - val_loss: 0.6732
# Epoch 135/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 1.0000 - loss: 0.0380 - val_accuracy: 0.7919 - val_loss: 0.6789
# Epoch 136/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 1.0000 - loss: 0.0386 - val_accuracy: 0.7919 - val_loss: 0.6729
# Epoch 137/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 1.0000 - loss: 0.0361 - val_accuracy: 0.7970 - val_loss: 0.6739
# Epoch 138/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 1.0000 - loss: 0.0364 - val_accuracy: 0.7919 - val_loss: 0.6783
# Epoch 139/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 1.0000 - loss: 0.0365 - val_accuracy: 0.7970 - val_loss: 0.6765
# Epoch 140/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 1.0000 - loss: 0.0369 - val_accuracy: 0.7970 - val_loss: 0.6728
# Epoch 141/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 1.0000 - loss: 0.0350 - val_accuracy: 0.7970 - val_loss: 0.6818
# Epoch 142/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 1.0000 - loss: 0.0347 - val_accuracy: 0.8020 - val_loss: 0.6670
# Epoch 143/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 1.0000 - loss: 0.0332 - val_accuracy: 0.7919 - val_loss: 0.6884
# Epoch 144/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 1.0000 - loss: 0.0336 - val_accuracy: 0.7970 - val_loss: 0.6699
# Epoch 145/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 1.0000 - loss: 0.0316 - val_accuracy: 0.7919 - val_loss: 0.6796
# Epoch 146/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 1.0000 - loss: 0.0325 - val_accuracy: 0.8020 - val_loss: 0.6797
# Epoch 147/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 1.0000 - loss: 0.0315 - val_accuracy: 0.7970 - val_loss: 0.6681
# Epoch 148/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 1.0000 - loss: 0.0321 - val_accuracy: 0.8020 - val_loss: 0.6754
# Epoch 149/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 1.0000 - loss: 0.0308 - val_accuracy: 0.8020 - val_loss: 0.6776
# Epoch 150/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 1.0000 - loss: 0.0301 - val_accuracy: 0.7919 - val_loss: 0.6814
# Epoch 151/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 1.0000 - loss: 0.0298 - val_accuracy: 0.7919 - val_loss: 0.6763
# Epoch 152/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 1.0000 - loss: 0.0300 - val_accuracy: 0.7919 - val_loss: 0.6865
# Epoch 153/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 1.0000 - loss: 0.0283 - val_accuracy: 0.7970 - val_loss: 0.6743
# Epoch 154/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 1.0000 - loss: 0.0286 - val_accuracy: 0.7919 - val_loss: 0.6899
# Epoch 155/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 1.0000 - loss: 0.0275 - val_accuracy: 0.8020 - val_loss: 0.6740
# Epoch 156/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 1.0000 - loss: 0.0277 - val_accuracy: 0.7970 - val_loss: 0.6799
# Epoch 157/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 1.0000 - loss: 0.0262 - val_accuracy: 0.7919 - val_loss: 0.6833
# Epoch 158/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 1.0000 - loss: 0.0262 - val_accuracy: 0.7919 - val_loss: 0.6897
# Epoch 159/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 1.0000 - loss: 0.0263 - val_accuracy: 0.7970 - val_loss: 0.6730
# Epoch 160/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 1.0000 - loss: 0.0266 - val_accuracy: 0.7919 - val_loss: 0.6903
# Epoch 161/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 1.0000 - loss: 0.0245 - val_accuracy: 0.8020 - val_loss: 0.6699
# Epoch 162/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 1.0000 - loss: 0.0257 - val_accuracy: 0.8020 - val_loss: 0.6878
# Epoch 163/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 1.0000 - loss: 0.0234 - val_accuracy: 0.8020 - val_loss: 0.6800
# Epoch 164/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 1.0000 - loss: 0.0239 - val_accuracy: 0.7970 - val_loss: 0.6990
# Epoch 165/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 1.0000 - loss: 0.0237 - val_accuracy: 0.8020 - val_loss: 0.6765
# Epoch 166/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 1.0000 - loss: 0.0229 - val_accuracy: 0.7919 - val_loss: 0.6911
# Epoch 167/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 1.0000 - loss: 0.0230 - val_accuracy: 0.8020 - val_loss: 0.6794
# Epoch 168/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 1.0000 - loss: 0.0237 - val_accuracy: 0.7970 - val_loss: 0.6936
# Epoch 169/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 1.0000 - loss: 0.0224 - val_accuracy: 0.7970 - val_loss: 0.6745
# Epoch 170/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 1.0000 - loss: 0.0219 - val_accuracy: 0.7919 - val_loss: 0.6944
# Epoch 171/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 1.0000 - loss: 0.0213 - val_accuracy: 0.8071 - val_loss: 0.6853
# Epoch 172/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 1.0000 - loss: 0.0209 - val_accuracy: 0.7970 - val_loss: 0.6872
# Epoch 173/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 1.0000 - loss: 0.0225 - val_accuracy: 0.7919 - val_loss: 0.6840
# Epoch 174/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 1.0000 - loss: 0.0210 - val_accuracy: 0.8020 - val_loss: 0.6843
# Epoch 175/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 1.0000 - loss: 0.0205 - val_accuracy: 0.7970 - val_loss: 0.6907
# Epoch 176/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 1.0000 - loss: 0.0198 - val_accuracy: 0.7970 - val_loss: 0.6879
# Epoch 177/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - accuracy: 1.0000 - loss: 0.0193 - val_accuracy: 0.7970 - val_loss: 0.6855
# Epoch 178/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 1.0000 - loss: 0.0203 - val_accuracy: 0.7970 - val_loss: 0.6962
# Epoch 179/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 1.0000 - loss: 0.0200 - val_accuracy: 0.8020 - val_loss: 0.6877
# Epoch 180/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 1.0000 - loss: 0.0187 - val_accuracy: 0.7970 - val_loss: 0.6913
# Epoch 181/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 1.0000 - loss: 0.0183 - val_accuracy: 0.7970 - val_loss: 0.6854
# Epoch 182/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 1.0000 - loss: 0.0186 - val_accuracy: 0.8020 - val_loss: 0.6918
# Epoch 183/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 1.0000 - loss: 0.0187 - val_accuracy: 0.8020 - val_loss: 0.6878
# Epoch 184/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 1.0000 - loss: 0.0186 - val_accuracy: 0.7970 - val_loss: 0.7005
# Epoch 185/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 1.0000 - loss: 0.0183 - val_accuracy: 0.8020 - val_loss: 0.6854
# Epoch 186/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 1.0000 - loss: 0.0178 - val_accuracy: 0.7970 - val_loss: 0.6975
# Epoch 187/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 1.0000 - loss: 0.0178 - val_accuracy: 0.8020 - val_loss: 0.6897
# Epoch 188/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 1.0000 - loss: 0.0172 - val_accuracy: 0.7970 - val_loss: 0.6966
# Epoch 189/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 1.0000 - loss: 0.0170 - val_accuracy: 0.8020 - val_loss: 0.6939
# Epoch 190/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 1.0000 - loss: 0.0169 - val_accuracy: 0.7970 - val_loss: 0.6882
# Epoch 191/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 1.0000 - loss: 0.0163 - val_accuracy: 0.7970 - val_loss: 0.6995
# Epoch 192/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 1.0000 - loss: 0.0166 - val_accuracy: 0.8020 - val_loss: 0.6879
# Epoch 193/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 1.0000 - loss: 0.0156 - val_accuracy: 0.7919 - val_loss: 0.7040
# Epoch 194/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 1.0000 - loss: 0.0159 - val_accuracy: 0.8020 - val_loss: 0.6964
# Epoch 195/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 1.0000 - loss: 0.0159 - val_accuracy: 0.8020 - val_loss: 0.6892
# Epoch 196/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 1.0000 - loss: 0.0151 - val_accuracy: 0.7919 - val_loss: 0.7083
# Epoch 197/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 1.0000 - loss: 0.0155 - val_accuracy: 0.8020 - val_loss: 0.6908
# Epoch 198/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 1.0000 - loss: 0.0152 - val_accuracy: 0.7970 - val_loss: 0.6997
# Epoch 199/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 1.0000 - loss: 0.0152 - val_accuracy: 0.8020 - val_loss: 0.6963
# Epoch 200/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 1.0000 - loss: 0.0151 - val_accuracy: 0.7970 - val_loss: 0.6989
# 16/16 - 0s - 4ms/step - accuracy: 0.7576 - loss: 0.9444
# Test Accuracy: 75.7638

# %%
print(f'Test Accuracy: {test_accuracy*100:.4f}')
# Out:
# Test Accuracy: 75.7638

# %%
y_pred = model.predict(X_test)
y_pred_labels = np.argmax(y_pred, axis=1)
y_test_labels = np.argmax(y_test, axis=1)
print(classification_report(y_test_labels, y_pred_labels))
# Out:
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
#               precision    recall  f1-score   support
#
#            0       0.82      0.74      0.78        38
#            1       0.78      0.80      0.79        81
#            2       0.84      0.66      0.74        73
#            3       0.67      0.83      0.74        71
#            4       0.83      0.83      0.83        69
#            5       0.83      0.74      0.78        80
#            6       0.62      0.64      0.63        45
#            7       0.64      0.79      0.71        34
#
#     accuracy                           0.76       491
#    macro avg       0.75      0.75      0.75       491
# weighted avg       0.77      0.76      0.76       491
